# %% [markdown]
# # 1110. Delete Nodes And Return Forest
# #### https://leetcode.com/problems/delete-nodes-and-return-forest/

# %% [markdown]
# # Approach 1: BFS

# %%
import collections
class Solution(object):
    def delNodes(self, root, to_delete):
        """
        :type root: TreeNode
        :type to_delete: List[int]
        :rtype: List[TreeNode]
        """
        res = []
        to_delete_set = set(to_delete)
    
        queue = collections.deque([(root, True)])

        while queue:
            cur, is_prev_del = queue.popleft()
            if cur.val not in to_delete_set and is_prev_del == True:
                res.append(cur)
            if cur.left:
                queue.append((cur.left, cur.val in to_delete_set))
                if cur.left.val in to_delete_set:
                    cur.left = None
            if cur.right:
                queue.append((cur.right, cur.val in to_delete_set))
                if cur.right.val in to_delete_set:
                    cur.right = None
        return res

# %% [markdown]
# # Approach 2: DFS

# %%
import collections
class Solution(object):
    def delNodes(self, root, to_delete):
        """
        :type root: TreeNode
        :type to_delete: List[int]
        :rtype: List[TreeNode]
        """
        res = []
        to_delete_set = set(to_delete)
        self.dfs(root, True, to_delete_set, res)
        return res
    
    def dfs(self, node, is_prev_del, to_delete_set, res):
        if node.val not in to_delete_set and is_prev_del == True:
            res.append(node)
        if node.left:
            self.dfs(node.left, node.val in to_delete_set, to_delete_set, res)
            if node.left.val in to_delete_set:
                node.left = None
        if node.right:
            self.dfs(node.right, node.val in to_delete_set, to_delete_set, res)
            if node.right.val in to_delete_set:
                node.right = None

# %% [markdown]
# # Verification

# %%
testcases = [("[1,2,3,4,5,6,7]", [3,5])]
expected = [["[1,2,null,4]","[6]","[7]"]]

outputs = []
sol = Solution();

for case in zip(testcases, expected):
    print("Input:    " + str(case[0]))
    node = stringToTreeNode(case[0][0])
    prettyPrintTree(node)
    outputs = sol.delNodes(node, case[0][1])
    for i in range(len(outputs)):
        outputs[i] = treeNodeToString(outputs[i])
    print("Output:   " + str(outputs))
    print("Expected: " + str(case[1]) + "\n")
# Out:
# Input:    ('[1,2,3,4,5,6,7]', [3, 5])
# │       ┌── 7
# │   ┌── 3
# │   │   └── 6
# └── 1
#     │   ┌── 5
#     └── 2
#         └── 4
# Output:   ['[1, 2, null, 4, null, null, null]', '[6, null, null]', '[7, null, null]']
# Expected: ['[1,2,null,4]', '[6]', '[7]']

# %%
# Definition for a binary tree node.
class TreeNode:
    def __init__(self, x):
        self.val = x
        self.left = None
        self.right = None

def treeNodeToString(root):
    if not root:
        return "[]"
    output = ""
    queue = [root]
    current = 0
    while current != len(queue):
        node = queue[current]
        current = current + 1

        if not node:
            output += "null, "
            continue

        output += str(node.val) + ", "
        queue.append(node.left)
        queue.append(node.right)
    return "[" + output[:-2] + "]"

def stringToTreeNode(input):
    input = input.strip()
    input = input[1:-1]
    if not input:
        return None

    inputValues = [s.strip() for s in input.split(',')]
    root = TreeNode(int(inputValues[0]))
    nodeQueue = [root]
    front = 0
    index = 1
    while index < len(inputValues):
        node = nodeQueue[front]
        front = front + 1

        item = inputValues[index]
        index = index + 1
        if item != "null":
            leftNumber = int(item)
            node.left = TreeNode(leftNumber)
            nodeQueue.append(node.left)

        if index >= len(inputValues):
            break

        item = inputValues[index]
        index = index + 1
        if item != "null":
            rightNumber = int(item)
            node.right = TreeNode(rightNumber)
            nodeQueue.append(node.right)
    return root

def prettyPrintTree(node, prefix="", isLeft=True):
    if not node:
        print("Empty Tree")
        return

    if node.right:
        prettyPrintTree(node.right, prefix + ("│   " if isLeft else "    "), False)

    print(prefix + ("└── " if isLeft else "┌── ") + str(node.val))

    if node.left:
        prettyPrintTree(node.left, prefix + ("    " if isLeft else "│   "), True)

def main():
    import sys

    def readlines():
        for line in sys.stdin:
            yield line.strip('\n')

    lines = readlines()
    while True:
        try:
            line = next(lines)
            node = stringToTreeNode(line)
            prettyPrintTree(node)
        except StopIteration:
            break


if __name__ == '__main__':
    main()
